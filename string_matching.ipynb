# %%
#
# SPDX-FileCopyrightText: Copyright 2022 Dilara Göksu
#

from copyrightDet.match_string import MatchString

corpus = ["Copyright (c) 1991-1995 Stichting Mathematisch Centrum Amsterdam The Netherlands",
          "Copyright (c) 1995-2001 Corporation for National Research Initiatives",
          "Copyright (c) 1995-2010 Free Software Foudation Inc",
          "Copyright (c) 2013 title from fe2.rs.github.com Github Inc.",
          "Copyright (c) 1999-2009, OW2 Consortium http://www.ow2.org/",
          "Copyright (c) 2002-2018 Pivotal, Inc.",
          "(c) September 2000",
          "(c) OoO.1 (c)",
          "U.S. Copyright Office",
          "Copyright Law",
          "Copyright Small Claims",
          "Search Copyright Records: Copyright Public Records Portal"]

match_string = MatchString()
for i in corpus:
    print("Original Document:", f"\n{i}\n", "\nPreprocessed Document:", f"\n{match_string.preprocess(i)}","\n\n")
# Out:
# Original Document:
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum Amsterdam The Netherlands
#
# Preprocessed Document:
# detected_copyright detected_copyright detected_year detected_year stichting mathematisch detected_person the netherlands detected_other_words
#
#
# Original Document:
# Copyright (c) 1995-2001 Corporation for National Research Initiatives
#
# Preprocessed Document:
# detected_copyright detected_copyright detected_year detected_year corporation for national research initiatives detected_other_words
#
#
# Original Document:
# Copyright (c) 1995-2010 Free Software Foudation Inc
#
# Preprocessed Document:
# detected_copyright detected_copyright detected_year detected_year free software foudation inc detected_other_words
#
#
# Original Document:
# Copyright (c) 2013 title from fe2.rs.github.com Github Inc.
#
# Preprocessed Document:
# detected_copyright detected_copyright detected_year title from fe2 rs github com detected_org detected_other_words
#
#
# Original Document:
# Copyright (c) 1999-2009, OW2 Consortium http://www.ow2.org/
#
# Preprocessed Document:
# detected_copyright detected_copyright detected_year detected_year ow2 consortium detected_url detected_other_words
#
#
# Original Document:
# Copyright (c) 2002-2018 Pivotal, Inc.
#
# Preprocessed Document:
# detected_copyright detected_copyright detected_year detected_year pivotal inc detected_other_words
#
#
# Original Document:
# (c) September 2000
#
# Preprocessed Document:
# detected_copyright september detected_year detected_other_words
#
#
# Original Document:
# (c) OoO.1 (c)
#
# Preprocessed Document:
# detected_copyright ooo 1 detected_copyright word_between_copyright detected_other_words
#
#
# Original Document:
# U.S. Copyright Office
#
# Preprocessed Document:
# detected_org
#
#
# Original Document:
# Copyright Law
#
# Preprocessed Document:
# detected_copyright law detected_other_words
#
#
# Original Document:
# Copyright Small Claims
#
# Preprocessed Document:
# detected_copyright small claims detected_other_words
#
#
# Original Document:
# Search Copyright Records: Copyright Public Records Portal
#
# Preprocessed Document:
# search detected_copyright records detected_copyright public records portal word_between_copyright detected_other_words
